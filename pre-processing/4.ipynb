# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("processed.hungarian.data", sep=",")
df.columns = ["age", "sex", "cp", "trestbps","chol","fbs","thalach","exang","restecg","oldpeak","slope","ca","thal","num"]
df
# Out:
#      age  sex  cp trestbps chol fbs thalach exang restecg  oldpeak slope ca  \
# 0     29    1   2      120  243   0       0   160       0      0.0     ?  ?
# 1     29    1   2      140    ?   0       0   170       0      0.0     ?  ?
# 2     30    0   1      170  237   0       1   170       0      0.0     ?  ?
# 3     31    0   2      100  219   0       1   150       0      0.0     ?  ?
# 4     32    0   2      105  198   0       0   165       0      0.0     ?  ?
# ..   ...  ...  ..      ...  ...  ..     ...   ...     ...      ...   ... ..
# 288   52    1   4      160  331   0       0    94       1      2.5     ?  ?
# 289   54    0   3      130  294   0       1   100       1      0.0     2  ?
# 290   56    1   4      155  342   1       0   150       1      3.0     2  ?
# 291   58    0   2      180  393   0       0   110       1      1.0     2  ?
# 292   65    1   4      130  275   0       1   115       1      1.0     2  ?
#
#     thal  num
# 0      ?    0
# 1      ?    0
# ...

# %%
x = df[df.columns[:-1:]]
y = df[df.columns[13]]

df.loc[df.G3 == "?" ,"G3"] = -1
x.loc[x.school == "GP",'school'] = -1

# %%
treinoX, testeX, treinoY, testeY = train_test_split(x,y,test_size=0.10)
knn = KNeighborsClassifier(n_neighbors=1, weights= "distance",metric="euclidean")
knn.fit(treinoX,treinoY)
y_pred = knn.predict(testeX)
y_true = testeY
#treinoX.loc[treinoX.school == "GP",'school'] = -1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/michel/Documentos/k-nn-classifier/pre-processing/4.ipynb Cell 4' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/michel/Documentos/k-nn-classifier/pre-processing/4.ipynb#ch0000003?line=0'>1</a> treinoX, testeX, treinoY, testeY = train_test_split(x,y,test_size=0.10)
#       <a href='vscode-notebook-cell:/home/michel/Documentos/k-nn-classifier/pre-processing/4.ipynb#ch0000003?line=1'>2</a> knn = KNeighborsClassifier(n_neighbors=1, weights= "distance",metric="euclidean")
# ----> <a href='vscode-notebook-cell:/home/michel/Documentos/k-nn-classifier/pre-processing/4.ipynb#ch0000003?line=2'>3</a> knn.fit(treinoX,treinoY)
#       <a href='vscode-notebook-cell:/home/michel/Documentos/k-nn-classifier/pre-processing/4.ipynb#ch0000003?line=3'>4</a> y_pred = knn.predict(testeX)
# ...
